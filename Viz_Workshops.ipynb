# %% [markdown]
# <a href="https://colab.research.google.com/github/BalkeesRekik/DS2002/blob/main/Viz_Workshops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Library 1: NetworkX

import networkx as nx

social_edges = [
    ('X', 'Y'),
    ('X', 'Z'),
    ('Y', 'W'),
    ('Z', 'V'),
    ('W', 'U'),
    ('V', 'T'),
    ('U', 'S'),
    ('T', 'R'),
    ('S', 'X'),
    ('R', 'Y')
]

G = nx.Graph()
G.add_edges_from(social_edges)

import matplotlib.pyplot as plt
plt.figure(figsize=(8, 8))
nx.draw(G, with_labels=True, node_color='lightblue', edge_color='gray', node_size=500)
plt.title('Social Network Graph')
plt.show()

# %%
# Library 2: Matplotlib

import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 15, 150)
y = np.tan(x)

plt.figure(figsize=(8, 5))
plt.plot(x, y, label='Tangent Wave', color='orange')
plt.title('Matplotlib Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.show()
